# %% [markdown]
# <a href="https://colab.research.google.com/github/dajley/Analyzing-Outliers/blob/main/Adding_Outliers_to_Main_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Adding Outliers to Main Dataset
#Code and Research by Dajanique Leysath

# %% [markdown]
# #Install Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# #Dataset

# %%
#Stores CSV file into dataframe
df = pd.read_csv('/content/drive/MyDrive/Datasets/df_main.csv')

# %%
df.head()
# Out:
#    Value  Avg Max Temp  Avg Min Temp  Avg Temp  Avg Bare Soil Temp  \
# 0  104.9       60.9285       37.1985   49.0635             50.2490
# 1   59.7       53.1395       31.8545   42.4970             47.2270
# 2   43.0       60.1670       33.7200   46.9435             52.5145
# 3   76.8       58.6490       32.1940   45.4220             52.1705
# 4   94.9       57.2660       34.1885   45.7275             49.0000
#
#    Avg Turf Soil Temp  Avg Wind Speed  Avg Max Wind Speed  Total Solar Rad  \
# 0             50.8615          7.8580             23.1800         489.1580
# 1             46.5050          9.8660             28.0395         447.4045
# 2             51.8025          7.5750             23.9520         442.3180
# 3             48.8195          8.3395             25.6365         488.8215
# 4             47.4995          7.5190             23.1775         396.1995
#
#    Avg Penman PET  Total Penman PET  Total Rainfall  Avg Dew Point  \
# 0          0.1835            5.6170          1.3810        34.8855
# 1          0.1910            5.8490          2.2715        30.7485
# 2          0.2075            6.3380          2.1860        28.4045
# 3          0.2055            6.2715          0.7400        30.5045
# 4          0.1680            5.1335          2.2735        32.6630
#
#    Avg Wind Chill
# 0         46.0855
# 1         37.6335
# 2         44.6370
# 3         42.3990
# 4         42.4450

# %%
df.shape
# Out:
# (286, 14)

# %%
df.columns[0]
# Out:
# 'Value'

# %%
df.columns[1:14]
# Out:
# Index(['Avg Max Temp', 'Avg Min Temp', 'Avg Temp', 'Avg Bare Soil Temp',
#        'Avg Turf Soil Temp', 'Avg Wind Speed', 'Avg Max Wind Speed',
#        'Total Solar Rad', 'Avg Penman PET', 'Total Penman PET',
#        'Total Rainfall', 'Avg Dew Point', 'Avg Wind Chill'],
#       dtype='object')

# %% [markdown]
# #Add Outliers

# %%
#Function that gets 10 random values from columns
#Multiplies five values by 10
#Divides five values by 10
def modify_random_values(df, seed=None):

    if seed is not None:
        np.random.seed(seed)

    df_modified = df.copy()

    for col in df.columns:
        indices = np.random.choice(df.index, size=10, replace=False)
        df_modified.loc[indices[:5], col] *= 10
        df_modified.loc[indices[5:], col] /= 10

    return df_modified

# Modify the DataFrame
df_modified = modify_random_values(df, seed=42)

# %%
#Columns to modify
cols_to_modify = df.columns[1:14]

#Create a boolean mask where values differ
diff_mask = df[cols_to_modify] != df_modified[cols_to_modify]

#Extract only the differing values from original and modified
diff_original = df[cols_to_modify].where(diff_mask)
diff_modified = df_modified[cols_to_modify].where(diff_mask)

#Combine into a multi-index DataFrame for easier comparison
diff_combined = pd.concat(
    [diff_original.stack(), diff_modified.stack()],
    axis=1,
    keys=['Original', 'Modified']
)

print("Differences between original and modified DataFrames:\n")
print(diff_combined)
# Out:
# Differences between original and modified DataFrames:
#
#                         Original   Modified
# 7   Avg Turf Soil Temp   50.0910    5.00910
# 9   Total Penman PET      6.4035    0.64035
# 12  Avg Bare Soil Temp   50.3635    5.03635
#     Total Rainfall        2.3415   23.41500
# 13  Avg Wind Chill       49.5795  495.79500
# ...                          ...        ...
# 267 Avg Max Wind Speed   27.6480  276.48000
# 268 Avg Max Wind Speed   25.5940    2.55940
# 272 Avg Penman PET        0.2065    0.02065
# 277 Avg Bare Soil Temp   53.8515  538.51500
# 278 Avg Wind Chill       39.2615  392.61500
#
# [130 rows x 2 columns]

# %%
diff_original.shape
# Out:
# (286, 13)

# %%
diff_modified.shape
# Out:
# (286, 13)

# %%
diff_combined.shape
# Out:
# (130, 2)

# %%
diff_combined.head(10)
# Out:
#                        Original    Modified
# 7  Avg Turf Soil Temp   50.0910     5.00910
# 9  Total Penman PET      6.4035     0.64035
# 12 Avg Bare Soil Temp   50.3635     5.03635
#    Total Rainfall        2.3415    23.41500
# 13 Avg Wind Chill       49.5795   495.79500
# 14 Avg Bare Soil Temp   50.1205   501.20500
# 15 Avg Bare Soil Temp   48.1250   481.25000
# 20 Avg Turf Soil Temp   48.8195     4.88195
# 21 Total Solar Rad     494.1390  4941.39000
# 22 Avg Bare Soil Temp   54.9050   549.05000
